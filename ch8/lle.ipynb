# %% [markdown]
# # LLE
#
# 지역 선형 임베딩(Locally Linear Embedding, LLE)는 비선형 차원 축소(Non Linear Dimensionality Reduction, NLDR) 기술이다.
#
# LLE는 먼저 각 훈련 샘플이 가장 가까운 이웃(closest neighbor)에 얼마나 선형적으로 연관되어 있는지를 측정한다. 그 후, 국부적인 관계가 가장 잘 보존되는 훈련 세트의 저차원 표현을 찾는다.
#
# 다음은 사이킷런의 `LocallyLinearEmbedding`을 사용해 스위스 롤을 펼치는 예이다.

# %%
from sklearn.datasets import make_swiss_roll
from sklearn.manifold import LocallyLinearEmbedding

X, t = make_swiss_roll(n_samples=1000, noise=0.2, random_state=41)

lle = LocallyLinearEmbedding(n_components=2, n_neighbors=10)
X_reduced = lle.fit_transform(X)

# %%
import matplotlib.pyplot as plt

plt.title("Unrolled swiss roll using LLE", fontsize=14)
plt.scatter(X_reduced[:, 0], X_reduced[:, 1], c=t, cmap=plt.cm.hot)
plt.xlabel("$z_1$", fontsize=18)
plt.ylabel("$z_2$", fontsize=18)
plt.axis([-0.065, 0.055, -0.1, 0.12])
plt.grid(True)

plt.show()

# %% [markdown]
# 위 결과를 보면, 지역적 샘플간 거리는 잘 보존되어 있지만 전체적으로는 그렇지 않은 것을 알 수 있다.
